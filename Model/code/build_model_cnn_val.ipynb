# %%
import numpy as np
import pandas as pd
import torch
from tqdm.notebook import tqdm,trange
import torch.nn as nn

# %%
df=pd.read_csv('100計數_地段率.csv',encoding='UTF-8')

# %%
data=np.zeros((141,132,28))
label=np.zeros((141,132,1))
for x in range(len(data)):
    for y in range(len(data[0])):
        id=141*y+x
        datadict={
            0:'活動中心',
            1:'郵局',
            2:'公車站',
            3:'火車站',
            4:'加油站',
            5:'停車場',
            6:'腳踏車',
            7:'寺廟',
            8:'大賣場',
            9:'服飾',
            10:'便利商店',
            11:'超市美妝',
            12:'電子賣場',
            13:'銀行',
            14:'ATM',
            15:'大學',
            16:'高中',
            17:'國小',
            18:'國中',
            19:'補習班',
            20:'嫌惡設施_危險',
            21:'嫌惡設施_殯葬',
            22:'嫌惡設施_髒亂',
            23:'食物',
            24:'診所',
            25:'醫院',
            26:'禮品百貨',
            27:'觀光景點',
        }
        label[x][y][0]=df.iloc[id]['平均地段率']
        for i in range(28):
            data[x][y][i]=df.iloc[id][datadict[i]]

# %%
validnum=len(df[df['平均地段率']>0.1])
print(validnum)
validdata=np.zeros((len(df[df['平均地段率']>0.1]),28,11,11))
validlabel=np.zeros((len(df[df['平均地段率']>0.1]),1))
counter=0
for y in trange(len(data[0])):
    for x in range(len(data)):
        if label[x][y][0]>0.5:
            for i in range(28):
                tempx=x-5
                tempy=y-5
                for a in range(11):
                    for b in range(11):
                        try:
                            validdata[counter][i][a][b]+=data[tempx+a][tempy+b][i]
                        except:
                            continue
            validlabel[counter][0]=label[x][y][0]-80    
            counter=counter+1
# Out:
# 2671
#   0%|          | 0/132 [00:00<?, ?it/s]

# %%
from torch.utils.data import Dataset, DataLoader
class ExampleDataset(Dataset):

    # data loading
    def __init__(self,tr,target, length):
        
        self.x = tr.astype(np.float32)
        self.y = target.astype(np.float32)
        self.n_samples = length

    # working for indexing
    def __getitem__(self, index):
        
        return self.x[index], self.y[index]

    # return the length of our dataset
    def __len__(self):
        
        return self.n_samples

# %%
tr0_set=ExampleDataset(validdata[0:2200],validlabel[0:2200],2200)
dataloader = DataLoader(tr0_set, batch_size=20, shuffle=True)
val_set=ExampleDataset(validdata[2200:],validlabel[2200:],(len(validdata)-2200))
dataloader_val = DataLoader(val_set, batch_size=20, shuffle=False)

# %%
import torch.nn as nn
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self):
        super(NeuralNet, self).__init__()
        # self.cv2_1=nn.Conv2d(28, 64, 3, stride=1)
        # self.cv2_2=nn.Conv2d(64, 128, 3, stride=1)
        # self.cv2_3=nn.Conv2d(128, 256, 5, stride=1)

        # self.layer1 = nn.Linear(3*3*256, 128)
        # self.layer2 = nn.Linear(128, 32)
        # self.out = nn.Linear(32, 1) 

        # self.ba1=nn.BatchNorm1d(256)
        # self.ba2=nn.BatchNorm1d(128)

        # self.act_fn1 = nn.ReLU()
        # self.act_fn2 = nn.ReLU()
        # self.act_fn3 = nn.ReLU()
        # self.act_fn4 = nn.ReLU()
        # Define your neural network here
        # TODO: How to modify this model to achieve better performance?
        self.net = nn.Sequential(
            nn.Conv2d(28, 64, 3, stride=1),
            nn.ReLU(),
            nn.Conv2d(64, 256, 5, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(5*5*256, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 1) 
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        out=self.net(x)
        
        return out

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # TODO: you may implement L1/L2 regularization here
        lamb = 0.0003
        if lamb :
          l2_reg = torch.tensor(0.).to('cuda')
          for param in self.parameters() :
            l2_reg += torch.norm(param)
          return self.criterion(pred, target) + l2_reg*lamb
        else : 
          return self.criterion(pred, target)

# %%
import torch.optim as optim

def train(tr_set, val_set, model, device):
    ''' DNN training '''
    criterion = nn.MSELoss()
    n_epochs = 50  # Maximum number of epochs
    best_loss = 0.0
    # Setup optimizer
    optimizer = optim.Adam(model.parameters(), lr=1E-3,weight_decay=0.00002)   

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    best_loss = 100000.0
    while epoch < n_epochs:
        train_loss = 0.0
        val_acc = 0.0
        val_loss = 0.0
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, labels = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            outputs = model(x)                     # forward pass (compute output)
            mse_loss = criterion(outputs, labels)  # compute loss
            _, train_pred = torch.max(outputs, 1)
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            train_loss += mse_loss.item()

        # After each epoch, test your model on the validation (development) set.
        if len(val_set) > 0:
            model.eval() # set the model to evaluation mode
            with torch.no_grad():
                for i, data in enumerate(val_set):
                    inputs, labels = data
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    batch_loss = criterion(outputs, labels) 
                    _, val_pred = torch.max(outputs, 1) 
                    an= torch.max(labels) 
                    val_loss += batch_loss.item()

                print('[{:03d}/{:03d}]  Loss: {:3.6f} | loss: {:3.6f}'.format(
                    epoch + 1, n_epochs, train_loss/len(tr_set),  val_loss/len(val_set)
                ))

                # if the model improves, save a checkpoint at this epoch
                if val_loss < best_loss:
                    best_loss = val_loss
                    torch.save(model, "D:\程式\google map api\model_cnn.pth")
                    print('saving model with loss {:.3f}'.format(best_loss/len(val_set)))
        else:
            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                epoch + 1, n_epochs, train_loss/len(tr_set), train_loss/len(tr_set)
            ))
        epoch += 1
    # if not validating, save the last epoch
    if len(val_set) == 0:
        torch.save(model, 'model.pth')
        print('saving model at last epoch')

    return min_mse, loss_record

# %%
model = NeuralNet().to('cuda')  # Construct model and move to device
model_loss, model_loss_record = train(dataloader, dataloader_val, model, 'cuda')
# Out:
# [001/150]  Loss: 332.523029 | loss: 92.370090
# saving model with loss 92.370
# [002/150]  Loss: 73.127833 | loss: 75.918953
# saving model with loss 75.919
# [003/150]  Loss: 64.624662 | loss: 74.794698
# saving model with loss 74.795
# [004/150]  Loss: 59.932119 | loss: 69.838322
# saving model with loss 69.838
# [005/150]  Loss: 50.684487 | loss: 62.200530
# saving model with loss 62.201
# [006/150]  Loss: 48.908293 | loss: 74.767385
# [007/150]  Loss: 43.470628 | loss: 70.640494
# [008/150]  Loss: 40.807780 | loss: 72.228680
# [009/150]  Loss: 41.860346 | loss: 71.851498
# [010/150]  Loss: 36.255664 | loss: 74.895319
# [011/150]  Loss: 31.420035 | loss: 75.108617
# [012/150]  Loss: 26.487556 | loss: 82.869577
# [126/150]  Loss: 0.722711 | loss: 115.633802
# [127/150]  Loss: 0.847241 | loss: 117.692200
# [128/150]  Loss: 0.588644 | loss: 117.357645
# [129/150]  Loss: 0.513223 | loss: 113.117311
# [130/150]  Loss: 0.594561 | loss: 116.243332
# [131/150]  Loss: 1.024534 | loss: 114.085973
# [132/150]  Loss: 1.236431 | loss: 109.990756
# [133/150]  Loss: 1.445416 | loss: 116.396055
# [134/150]  Loss: 1.289031 | loss: 112.593243
# [135/150]  Loss: 1.111589 | loss: 113.290577
# [136/150]  Loss: 0.938280 | loss: 114.884392
# [137/150]  Loss: 0.537128 | loss: 113.693543
# [138/150]  Loss: 0.681534 | loss: 114.666119
# [139/150]  Loss: 0.755637 | loss: 116.068444
# [140/150]  Loss: 0.574421 | loss: 115.411938
# [141/150]  Loss: 0.719779 | loss: 114.272120
# [142/150]  Loss: 0.545731 | loss: 112.761024
# [143/150]  Loss: 0.536928 | loss: 115.534951
# [144/150]  Loss: 0.544393 | loss: 114.607631
# [145/150]  Loss: 0.457691 | loss: 114.277354
# [146/150]  Loss: 0.667498 | loss: 113.073990
# [147/150]  Loss: 0.968943 | loss: 114.399358
# [148/150]  Loss: 0.930708 | loss: 115.284680
# [149/150]  Loss: 0.870121 | loss: 111.580117
# [150/150]  Loss: 0.829053 | loss: 116.337422

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(model_loss_record['train'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.ion()

fig = plt.figure()
plt.plot(model_loss_record['train'][5:])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
fig.savefig('train100loss.jpg')

# %%
model=torch.load("D:\程式\google map api\model_cnn.pth")
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

count=0
prd_err=[]
tt_set = DataLoader(validdata.astype(np.float32), batch_size=1, shuffle=False)
preds = test(tt_set, model, 'cuda')  # predict COVID-19 cases with your model
for i in range(len(preds)):
    if preds[i] - validlabel[i] > 10 or preds[i] - validlabel[i] < -10:
        print("實際值:",validlabel[i],"預測結果:",preds[i],"id:",i)
        count+=1
        prd_err.append(i)


print("預測錯誤數量:",count)
prd_err=pd.DataFrame(prd_err)
prd_err.to_csv("prd_err_cnn.csv",index=False)
# Out:
# 實際值: [20.] 預測結果: [34.73747] id: 9
# 實際值: [20.] 預測結果: [34.25507] id: 10
# 實際值: [20.] 預測結果: [34.25624] id: 11
# 實際值: [20.] 預測結果: [32.6194] id: 12
# 實際值: [20.] 預測結果: [32.864277] id: 13
# 實際值: [20.] 預測結果: [32.799156] id: 14
# 實際值: [20.] 預測結果: [32.346462] id: 15
# 實際值: [20.] 預測結果: [32.324055] id: 16
# 實際值: [20.] 預測結果: [32.17127] id: 17
# 實際值: [20.] 預測結果: [32.983097] id: 21
# 實際值: [20.] 預測結果: [32.01809] id: 22
# 實際值: [20.] 預測結果: [31.685392] id: 23
# 實際值: [20.] 預測結果: [31.43438] id: 24
# 實際值: [20.] 預測結果: [31.578375] id: 25
# 實際值: [20.] 預測結果: [31.90703] id: 26
# 實際值: [20.] 預測結果: [32.296566] id: 27
# 實際值: [20.] 預測結果: [32.214764] id: 32
# 實際值: [20.] 預測結果: [31.886995] id: 33
# 實際值: [20.] 預測結果: [33.03857] id: 1359
# 實際值: [50.] 預測結果: [66.69566] id: 1365
# 實際值: [50.] 預測結果: [38.772686] id: 1378
# 實際值: [50.] 預測結果: [60.348415] id: 1384
# 實際值: [80.] 預測結果: [66.899765] id: 1385
# 實際值: [43.] 預測結果: [53.080105] id: 1394
# 實際值: [57.] 預測結果: [68.025116] id: 1405
# 實際值: [80.] 預測結果: [59.419132] id: 1408
# 實際值: [37.] 預測結果: [51.2589] id: 1414
# 實際值: [90.] 預測結果: [79.69609] id: 1423
# 實際值: [68.] 預測結果: [56.8218] id: 1427
# 實際值: [20.] 預測結果: [30.377195] id: 1442
# 實際值: [75.] 預測結果: [85.589905] id: 1446
# 實際值: [90.] 預測結果: [74.87615] id: 1447
# 實際值: [76.] 預測結果: [60.991325] id: 1454
# 實際值: [50.] 預測結果: [38.781246] id: 1467
# 實際值: [10.] 預測結果: [22.952381] id: 1472
# 實際值: [10.] 預測結果: [26.760008] id: 1473
# 實際值: [60.] 預測結果: [75.867035] id: 1474
# 實際值: [76.] 預測結果: [61.303185] id: 1482
# 實際值: [70.] 預測結果: [59.90109] id: 1483
# 實際值: [65.] 預測結果: [53.143066] id: 1488
# 實際值: [10.] 預測結果: [22.058163] id: 1504
# 實際值: [10.] 預測結果: [25.853268] id: 1505
# 實際值: [50.] 預測結果: [67.08711] id: 1507
# 實際值: [83.] 預測結果: [60.018497] id: 1509
# 實際值: [90.] 預測結果: [58.09367] id: 1510
# 實際值: [75.] 預測結果: [57.380207] id: 1511
# 實際值: [90.] 預測結果: [64.37298] id: 1512
# 實際值: [80.] 預測結果: [63.901592] id: 1513
# 實際值: [83.] 預測結果: [60.419544] id: 1514
# 實際值: [40.] 預測結果: [50.302807] id: 1527
# 實際值: [50.] 預測結果: [39.92587] id: 1528
# 實際值: [25.] 預測結果: [12.414642] id: 1536
# 實際值: [15.] 預測結果: [25.596945] id: 1540
# 實際值: [75.] 預測結果: [90.155945] id: 1541
# 實際值: [90.] 預測結果: [77.01277] id: 1542
# 實際值: [90.] 預測結果: [67.58005] id: 1543
# 實際值: [90.] 預測結果: [63.525047] id: 1544
# 實際值: [40.] 預測結果: [56.167286] id: 1545
# 實際值: [48.] 預測結果: [58.457508] id: 1549
# 實際值: [43.] 預測結果: [56.272476] id: 1550
# 實際值: [40.] 預測結果: [51.524826] id: 1564
# 實際值: [55.] 預測結果: [71.68605] id: 1581
# 實際值: [50.] 預測結果: [63.21389] id: 1582
# 實際值: [66.] 預測結果: [55.767086] id: 1588
# 實際值: [30.] 預測結果: [40.99406] id: 1594
# 實際值: [52.] 預測結果: [40.710667] id: 1595
# 實際值: [60.] 預測結果: [41.9041] id: 1682
# 實際值: [60.] 預測結果: [40.097668] id: 1683
# 實際值: [60.] 預測結果: [38.600933] id: 1684
# 實際值: [54.] 預測結果: [38.773983] id: 1685
# 實際值: [70.] 預測結果: [53.75809] id: 1696
# 實際值: [35.] 預測結果: [50.16912] id: 1710
# 實際值: [30.] 預測結果: [41.126804] id: 1718
# 實際值: [60.] 預測結果: [41.54707] id: 1719
# 實際值: [60.] 預測結果: [41.467876] id: 1720
# 實際值: [60.] 預測結果: [41.23567] id: 1721
# 實際值: [50.] 預測結果: [39.940502] id: 1722
# 實際值: [60.] 預測結果: [41.330276] id: 1725
# 實際值: [30.] 預測結果: [40.73337] id: 1750
# 實際值: [30.] 預測結果: [40.43285] id: 1751
# 實際值: [60.] 預測結果: [39.535942] id: 1752
# 實際值: [60.] 預測結果: [40.28494] id: 1753
# 實際值: [60.] 預測結果: [40.224545] id: 1754
# 實際值: [60.] 預測結果: [40.082523] id: 1755
# 實際值: [60.] 預測結果: [40.377323] id: 1756
# 實際值: [60.] 預測結果: [38.813328] id: 1757
# 實際值: [70.] 預測結果: [58.3214] id: 1758
# 實際值: [67.] 預測結果: [54.662193] id: 1760
# 實際值: [70.] 預測結果: [55.868874] id: 1761
# 實際值: [60.] 預測結果: [47.469517] id: 1763
# 實際值: [60.] 預測結果: [47.492203] id: 1765
# 實際值: [28.] 預測結果: [40.252987] id: 1778
# 實際值: [40.] 預測結果: [51.928158] id: 1787
# 實際值: [40.] 預測結果: [50.020115] id: 1798
# 實際值: [35.] 預測結果: [46.910725] id: 1799
# 實際值: [40.] 預測結果: [53.749424] id: 1807
# 實際值: [80.] 預測結果: [59.031002] id: 1808
# 實際值: [35.] 預測結果: [47.83358] id: 1822
# 實際值: [40.] 預測結果: [51.533978] id: 1830
# 實際值: [70.] 預測結果: [57.33792] id: 1831
# 實際值: [65.] 預測結果: [52.885956] id: 1832
# 實際值: [60.] 預測結果: [49.405834] id: 1855
# 實際值: [68.] 預測結果: [54.383434] id: 1856
# 實際值: [40.] 預測結果: [50.17557] id: 1876
# 實際值: [80.] 預測結果: [49.604435] id: 1897
# 實際值: [55.] 預測結果: [42.607014] id: 1900
# 實際值: [60.] 預測結果: [46.085583] id: 1916
# 實際值: [60.] 預測結果: [48.120052] id: 1917
# 實際值: [60.] 預測結果: [46.647175] id: 1925
# 實際值: [58.] 預測結果: [47.74871] id: 1941
# 實際值: [61.] 預測結果: [48.555862] id: 1976
# 實際值: [50.] 預測結果: [37.77643] id: 1982
# 實際值: [48.] 預測結果: [37.790546] id: 2010
# 實際值: [50.] 預測結果: [39.60965] id: 2013
# 實際值: [60.] 預測結果: [48.48748] id: 2016
# 實際值: [58.] 預測結果: [41.123768] id: 2025
# 實際值: [61.] 預測結果: [49.406387] id: 2031
# 實際值: [50.] 預測結果: [37.71951] id: 2049
# 實際值: [70.] 預測結果: [46.085464] id: 2057
# 實際值: [70.] 預測結果: [50.543247] id: 2070
# 實際值: [51.] 預測結果: [40.781326] id: 2088
# 實際值: [66.] 預測結果: [45.638794] id: 2104
# 實際值: [60.] 預測結果: [41.245358] id: 2108
# 實際值: [58.] 預測結果: [43.64519] id: 2113
# 實際值: [70.] 預測結果: [48.504288] id: 2115
# 實際值: [30.] 預測結果: [40.007805] id: 2134
# 實際值: [30.] 預測結果: [40.041523] id: 2135
# 實際值: [35.] 預測結果: [45.041508] id: 2149
# 實際值: [67.] 預測結果: [45.37534] id: 2150
# 實際值: [30.] 預測結果: [41.111393] id: 2155
# 實際值: [30.] 預測結果: [40.79127] id: 2159
# 實際值: [60.] 預測結果: [43.8877] id: 2160
# 實際值: [70.] 預測結果: [46.045002] id: 2161
# 實際值: [40.] 預測結果: [51.2319] id: 2183
# 實際值: [56.] 預測結果: [43.62367] id: 2193
# 實際值: [60.] 預測結果: [41.248867] id: 2195
# 實際值: [30.] 預測結果: [42.69176] id: 2196
# 實際值: [30.] 預測結果: [42.340965] id: 2197
# 實際值: [60.] 預測結果: [40.731876] id: 2201
# 實際值: [30.] 預測結果: [40.069504] id: 2223
# 實際值: [67.] 預測結果: [44.023617] id: 2235
# 實際值: [30.] 預測結果: [43.4632] id: 2238
# 實際值: [31.] 預測結果: [44.390713] id: 2239
# 實際值: [37.] 預測結果: [47.93004] id: 2274
# 實際值: [33.] 預測結果: [44.202343] id: 2278
# 實際值: [34.] 預測結果: [46.015293] id: 2279
# 實際值: [35.] 預測結果: [46.084297] id: 2280
# 實際值: [30.] 預測結果: [42.35277] id: 2286
# 實際值: [40.] 預測結果: [50.02284] id: 2309
# 實際值: [30.] 預測結果: [40.773415] id: 2325
# 實際值: [60.] 預測結果: [45.508327] id: 2345
# 實際值: [60.] 預測結果: [45.172592] id: 2350
# 實際值: [35.] 預測結果: [47.665447] id: 2370
# 實際值: [30.] 預測結果: [41.384975] id: 2396
# 實際值: [32.] 預測結果: [42.45016] id: 2397
# 實際值: [35.] 預測結果: [47.87762] id: 2401
# 實際值: [45.] 預測結果: [34.109417] id: 2404
# 實際值: [45.] 預測結果: [34.75105] id: 2405
# 實際值: [32.] 預測結果: [45.375996] id: 2418
# 實際值: [31.] 預測結果: [43.096592] id: 2419
# 實際值: [30.] 預測結果: [43.095222] id: 2420
# 實際值: [30.] 預測結果: [42.02092] id: 2421
# 實際值: [30.] 預測結果: [41.99018] id: 2422
# 實際值: [30.] 預測結果: [41.268295] id: 2423
# 實際值: [30.] 預測結果: [40.722527] id: 2424
# 實際值: [50.] 預測結果: [38.507114] id: 2427
# 實際值: [35.] 預測結果: [46.45023] id: 2429
# 實際值: [47.] 預測結果: [35.704613] id: 2442
# 實際值: [32.] 預測結果: [43.075687] id: 2446
# 實際值: [30.] 預測結果: [48.613247] id: 2448
# 實際值: [30.] 預測結果: [46.63123] id: 2449
# 實際值: [32.] 預測結果: [47.154957] id: 2450
# 實際值: [32.] 預測結果: [46.03259] id: 2451
# 實際值: [30.] 預測結果: [45.486965] id: 2452
# 實際值: [30.] 預測結果: [42.974255] id: 2453
# 實際值: [35.] 預測結果: [45.01968] id: 2461
# 實際值: [36.] 預測結果: [50.006783] id: 2482
# 實際值: [36.] 預測結果: [48.59898] id: 2485
# 實際值: [31.] 預測結果: [47.556416] id: 2486
# 實際值: [34.] 預測結果: [44.39636] id: 2487
# 實際值: [50.] 預測結果: [38.35021] id: 2492
# 實際值: [50.] 預測結果: [38.16003] id: 2508
# 實際值: [30.] 預測結果: [48.0172] id: 2516
# 實際值: [30.] 預測結果: [44.8418] id: 2517
# 實際值: [30.] 預測結果: [41.37287] id: 2518
# 實際值: [60.] 預測結果: [39.504345] id: 2522
# 實際值: [50.] 預測結果: [37.148937] id: 2523
# 實際值: [50.] 預測結果: [35.444935] id: 2524
# 實際值: [48.] 預測結果: [35.681164] id: 2525
# 實際值: [60.] 預測結果: [38.921253] id: 2530
# 實際值: [50.] 預測結果: [36.90433] id: 2531
# 實際值: [47.] 預測結果: [35.99403] id: 2532
# 實際值: [57.] 預測結果: [37.82984] id: 2541
# 實際值: [50.] 預測結果: [37.194] id: 2542
# 實際值: [50.] 預測結果: [35.49046] id: 2543
# 實際值: [48.] 預測結果: [35.337208] id: 2544
# 實際值: [53.] 預測結果: [36.333797] id: 2555
# 實際值: [52.] 預測結果: [35.356224] id: 2556
# 實際值: [49.] 預測結果: [34.75012] id: 2557
# 實際值: [47.] 預測結果: [34.6366] id: 2569
# 實際值: [44.] 預測結果: [33.902653] id: 2570
# 實際值: [60.] 預測結果: [35.50026] id: 2585
# 實際值: [50.] 預測結果: [34.491783] id: 2586
# 實際值: [50.] 預測結果: [34.118282] id: 2587
# 實際值: [49.] 預測結果: [34.153732] id: 2588
# 實際值: [50.] 預測結果: [36.492847] id: 2589
# 實際值: [50.] 預測結果: [39.778343] id: 2590
# 實際值: [50.] 預測結果: [35.303013] id: 2601
# 實際值: [55.] 預測結果: [35.26714] id: 2602
# 實際值: [50.] 預測結果: [34.468983] id: 2603
# 實際值: [50.] 預測結果: [34.3439] id: 2604
# 實際值: [50.] 預測結果: [34.308826] id: 2605
# 實際值: [48.] 預測結果: [36.227806] id: 2606
# 實際值: [50.] 預測結果: [38.57827] id: 2607
# 實際值: [53.] 預測結果: [35.18255] id: 2620
# 實際值: [47.] 預測結果: [34.64089] id: 2621
# 實際值: [46.] 預測結果: [34.376213] id: 2623
# 實際值: [53.] 預測結果: [35.253246] id: 2635
# 實際值: [50.] 預測結果: [33.981716] id: 2636
# 實際值: [50.] 預測結果: [39.349236] id: 2640
# 實際值: [60.] 預測結果: [35.66396] id: 2651
# 實際值: [50.] 預測結果: [34.129734] id: 2652
# 實際值: [45.] 預測結果: [33.158634] id: 2653
# 實際值: [45.] 預測結果: [33.204082] id: 2654
# 實際值: [50.] 預測結果: [35.816433] id: 2656
# 實際值: [50.] 預測結果: [38.54439] id: 2658
# 實際值: [50.] 預測結果: [39.48249] id: 2664
# 實際值: [50.] 預測結果: [38.025272] id: 2670
# 預測錯誤數量: 396

# %%
#real data(all)


realdata=np.zeros((len(df['id']),28,11,11))
reallabel=np.zeros((len(df['id']),1))
counter=0
for y in trange(len(data[0])):
    for x in range(len(data)):
        for i in range(28):
            tempx=x-5
            tempy=y-5
            for a in range(11):
                for b in range(11):
                    try:
                        realdata[counter][i][a][b]+=data[tempx+a][tempy+b][i]
                    except:
                        continue
        reallabel[counter][0]=label[x][y][0]-80    
        counter=counter+1
tt_set = DataLoader(realdata.astype(np.float32), batch_size=1, shuffle=False)
preds = test(tt_set, model, 'cuda')  # predict COVID-19 cases with your model
# Out:
#   0%|          | 0/132 [00:00<?, ?it/s]

# %%
import math
err=[]
pred=[]
for i in range(len(preds)):
    ##err.append(abs(preds[i][0]-reallabel[i][0]))
    pred.append(preds[i][0]+80)

# %%
print(len(pred))
# Out:
# 18612

# %%
df['預測值']=pred
df.to_csv('result100all_cnn.csv')

# %%
import json
with open('100計數_地段率.geojson', newline='',encoding="utf-8") as jsonfile:
    data = json.load(jsonfile)

for i in range(len(preds)):
    data['features'][i]['properties']['預測值']=pred[i]

print(data['features'][0]['properties'])
with open('100計數_地段率_preds_cnn.geojson', 'w',encoding="utf-8") as json_obj:
    json.dump(data, json_obj, ensure_ascii = False, indent=4)




with open('100計數_地段率_preds_cnn.geojson', newline='',encoding="utf-8") as jsonfile2:
    data2 = json.load(jsonfile2)
print(data2['features'][0]['properties'])
# Out:
# {'id': 1.0, 'left': 13373240.3256, 'top': 2635136.2672999995, 'right': 13373340.325599998, 'bottom': 2635036.2673, '活動中心': 0.0, '郵局': 0.0, '公車站': 0.0, '火車站': 0.0, '加油站': 0.0, '停車場': 0.0, '腳踏車': 0.0, '寺廟': 0.0, '大賣場': 0.0, '服飾': 0.0, '便利商店': 0.0, '超市美妝': 0.0, '電子賣場': 0.0, '銀行': 0.0, 'ATM': 0.0, '大學': 0.0, '高中': 0.0, '國小': 0.0, '國中': 0.0, '補習班': 0.0, '嫌惡設施_危險': 0.0, '嫌惡設施_殯葬': 0.0, '嫌惡設施_髒亂': 0.0, '食物': 0.0, '診所': 0.0, '醫院': 0.0, '禮品百貨': 0.0, '觀光景點': 0.0, '房屋稅數量': 0.0, '地段率總和': 0.0, '折舊年數總和': 0.0, '平均地段率': None, '平均折舊年數': None, 'EPSG3857_X': 13373290.325599998, 'EPSG3857_Y': 2635086.2672999995, '預測值': 118.66514587402344}
# {'id': 1.0, 'left': 13373240.3256, 'top': 2635136.2672999995, 'right': 13373340.325599998, 'bottom': 2635036.2673, '活動中心': 0.0, '郵局': 0.0, '公車站': 0.0, '火車站': 0.0, '加油站': 0.0, '停車場': 0.0, '腳踏車': 0.0, '寺廟': 0.0, '大賣場': 0.0, '服飾': 0.0, '便利商店': 0.0, '超市美妝': 0.0, '電子賣場': 0.0, '銀行': 0.0, 'ATM': 0.0, '大學': 0.0, '高中': 0.0, '國小': 0.0, '國中': 0.0, '補習班': 0.0, '嫌惡設施_危險': 0.0, '嫌惡設施_殯葬': 0.0, '嫌惡設施_髒亂': 0.0, '食物': 0.0, '診所': 0.0, '醫院': 0.0, '禮品百貨': 0.0, '觀光景點': 0.0, '房屋稅數量': 0.0, '地段率總和': 0.0, '折舊年數總和': 0.0, '平均地段率': None, '平均折舊年數': None, 'EPSG3857_X': 13373290.325599998, 'EPSG3857_Y': 2635086.2672999995, '預測值': 118.66514587402344}
